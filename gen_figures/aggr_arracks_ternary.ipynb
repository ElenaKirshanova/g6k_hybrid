# %%
import os, re
import time

import pickle 
import numpy as np
from hybrid_estimator.batchCVP import batchCVPP_cost
out_path = "lwe_instances/reduced_lattices/"

# with open( "./agr.pkl", "rb" ) as file:
#     otmp = pickle.load( file )

# o = []
# for oo in otmp:
#     if oo['kyb'][0] in [140,150,160]:
#         o.append( oo )

sec_type = "ternary"
sec_param = float(1/6)
q = 3329
dist=sec_type
dist_param=sec_param

with open("./lwe_instances/reduced_lattices/exp_[160, 170, 180, 190, 200]_3329_ternary_0.1667.pkl", "rb") as file:
    out = pickle.load( file )
    
lwe_inst = [ #do we need lats_per_dim and inst_per_lat?
    {"n": 160, "q": 3329, "dist": 'ternary', "dist_param": 0.16666666666666666},
    {"n": 170, "q": 3329, "dist": 'ternary', "dist_param": 0.16666666666666666},
    {"n": 180, "q": 3329, "dist": 'ternary', "dist_param": 0.16666666666666666},
    {"n": 190, "q": 3329, "dist": 'ternary', "dist_param": 0.16666666666666666},
    {"n": 200, "q": 3329, "dist": 'ternary', "dist_param": 0.16666666666666666},
]

hparams = { #n_guess_coord's, n_slicer_coord from preprocessing.py
    160: (6,51),
    170: (6,56),
    180: (6,64),
    190: (6,74),
    200: (6,83)
}

outpre = []
corresponding_blocksizes = {160:50, 170:50, 180:60, 190: 60, 200: 65}
for n in range(160,201,10):
    betapre = corresponding_blocksizes[n]
    for seed in range(10):
        filename = f"report_pre_{n}_{q}_{sec_type}_{dist_param:0.4f}_{seed}_{betapre}.pkl"
        with open( out_path + filename, "rb" ) as file:
            outpre.append( pickle.load( file ) )

print(f"len(outp): {len(out)}")
print(f"len(outpre): {len(outpre)}")

maxbeta = 0
for oo in out:
    if oo["beta"] > maxbeta:
        maxbeta = oo["beta"]

print( maxbeta )
# Out:
# len(outp): 500
# len(outpre): 50
# 89

# %%
l = {}
ddl = {}

#extracting the mean blocksize
for oo in out:
    if not oo["kyb"][0] in l.keys():
        l[oo["kyb"][0]] = [ oo["beta"], 1 ]
        ddl[oo["kyb"][0]] = [ oo["beta"] ]
    else:
        l[oo["kyb"][0]][0] += oo["beta"]
        l[oo["kyb"][0]][1] += 1
        ddl[oo["kyb"][0]].append( oo["beta"] )

for key in l.keys():
    l[key] = l[key][0]/l[key][1].n()
    ddl[key] = np.std(ddl[key])

l_primal = l
print( l_primal )
print( ddl )

P = list_plot(l, plotjoined=True, marker='.',color="red", legend_label="Experiment")

P.show( axes_labels=['$n$', '$\\beta$'], title=f'$\\beta$ sufficient to solve uSVP, Kyber-$n$. 5 tours progressive BKZ. 100 experiments.', figsize=12 )
# Out:
# {160: 52.8900000000000, 170: 58.2400000000000, 180: 66.1300000000000, 190: 75.6700000000000, 200: 83.8700000000000}
# {160: 2.111373960244845, 170: 2.0155396299750596, 180: 2.837798442454995, 190: 2.8001964216818793, 200: 2.2875969924792257}
# Graphics object consisting of 1 graphics primitive

# %%
from sample import Distribution, ternaryDist, centeredBinomial

from hybrid_estimator.batchCVP import batchCVPP_cost


if sec_type=="binomial":
    distrib = centeredBinomial(sec_param)
elif sec_type=="ternary":
     print(f"sec_param: {sec_param}")
     distrib = ternaryDist(sec_param)

# extracting the primal preprocessing timing
r = {}
for oo in outpre:
    n, seed = oo['kyb'][0], oo['kyb'][4][0]
    if not n in r.keys(): 
        r[n] = [ oo["time"], 1 ]
    else:
        r[n][0] += oo["time"]
        r[n][1] += 1


#averaging the timing
for key in r.keys():
    r[key] = r[key][0]/r[key][1].n()

# extracting the primal attack timing
l = {}
for oo in out:
    if not oo["kyb"][0] in l.keys():
        l[oo["kyb"][0]] = [ oo["time"], 1 ]
    else:
        l[oo["kyb"][0]][0] += oo["time"]
        l[oo["kyb"][0]][1] += 1

# averaging it
for key in l.keys():
    l[key] = l[key][0]/l[key][1].n() + r[key]
    ddl[key] = np.std(ddl[key])

primal_timings = deepcopy(l)
# - - - 
P = list_plot_semilogy(l, plotjoined=True, legend_label="Primal attack")

data = []
path = "./lwe_instances/reduced_lattices/"
# regex = re.compile(r'^report_prehyb_(\d+)_')
pattern = re.compile(r'''
    ^report_prehyb_             
    (?P<n>\d+)_                 
    (?P<q>\d+)_                 
    (?P<dist>[^_]+)_            
    (?P<dist_param>[+-]?\d+\.\d{4})_  
    (?P<seed>\d+)_              
    (?P<kappa>\d+)_             
    (?P<sieve_dim_min>\d+)_     
    (?P<sieve_dim_max>\d+)_     
    (?P<beta_bkz>\d+)           
    \.pkl$
''', re.VERBOSE)
regex = re.compile(pattern)

for path, directories, files in os.walk(path):
    for candidate in files:
        match = regex.match(candidate)
        if match and sec_type in candidate and f"{sec_param:0.4f}" in candidate:
            gd = match.groupdict()
            n             = int(gd['n'])
            q             = int(gd['q'])
            dist          = gd['dist']
            dist_param    = float(gd['dist_param'])
            seed          = int(gd['seed'])
            kappa         = int(gd['kappa'])
            sieve_dim_min = int(gd['sieve_dim_min'])
            sieve_dim_max = int(gd['sieve_dim_max'])
            beta_bkz      = int(gd['beta_bkz'])
            # print(f"n: {n} sec: {sec_type} {kappa}")
            print(f"{candidate}")
            try:
                # try:
                #     print(ncur)
                # except KeyError:
                #     continue
                try:
                    # print(
                    #     n in [tmp["n"] for tmp in lwe_inst] ,
                    #     kappa==hparams[n][0] ,
                    #     beta_bkz == hparams[n][1],
                    #     sec_type in candidate ,
                    #     f"{sec_param:0.4f}" in candidate ,
                    #     f"_{hparams[n][0]}_" in candidate
                    # )
                    if ( #ncur in [tmp["n"] for tmp in lwe_inst] and
                        n in [tmp["n"] for tmp in lwe_inst] and
                        kappa == hparams[n][0] and
                        beta_bkz == hparams[n][1] and
                        sec_type in candidate and
                        f"{sec_param:0.4f}" in candidate and
                        f"_{hparams[n][0]}_" in candidate
                    ):
                        with open( path+candidate, "rb" ) as file:
                            data.append( pickle.load(file) )
                except KeyError as err:
                    print( err )
                    pass
            except ValueError as expt:
                print(expt)
                pass

processed_data = {}
for D in data: #loading from the text output
    n, q, dist, sec_param, seed = D["params"]
    if dist != sec_type:
        print(f"wrong dist: {dist}")
        continue
    sieve_dim_max = D["sieve_dim_max"]
    sieve_dim_min = D["sieve_dim_min"]
    kappa = D["kappa"]
    if kappa != hparams[n][0]: #or sieve_dim_min != hparams[n][1]:
        continue
    
    bkz_runtime = D["bkz_runtime"]
    bdgl_runtime = D["bdgl_runtime"]

    nsampl = ceil( 2 ** ( distrib.entropy * kappa ) )

    for i in range(len(bdgl_runtime)):
        sievedim = sieve_dim_max-i
        latdim = n - kappa
        if not (n,kappa,sievedim,latdim) in processed_data.keys():
            processed_data[(n,kappa,sievedim,latdim)] = {"bkz_runtime": [], "bdgl_runtime": [], "succrate": 0.}
        processed_data[(n,kappa,sievedim,latdim)]["bkz_runtime"].append( bkz_runtime )
        processed_data[(n,kappa,sievedim,latdim)]["bdgl_runtime"].append( bdgl_runtime )

aggrigated_data = {}
for (n,k,sievedim,latdim) in processed_data.keys():
    D = processed_data[(n,k,sievedim,latdim)]
    bkz_runtime = np.mean( D["bkz_runtime"] )
    bdgl_runtime = np.mean( D["bdgl_runtime"], axis=int(0) )
    
    aggrigated_data[ (n,k,sievedim) ] =  bkz_runtime + np.zeros(len(bdgl_runtime))



l0, l1 = {}, {}

for (n,k,sievedim) in aggrigated_data.keys():
    l0[n] = aggrigated_data[(n,k,sievedim)][-1]
    l1[n] = aggrigated_data[(n,k,sievedim)][0]

print(l)
print(l1)

preprocess_hyb_time = deepcopy(l0)

P += list_plot_semilogy(l0, plotjoined=True, base=10, axes_labels=["$n$", "$log(T)$"], color="green", legend_label="Hybrid preprocessing")
P.show( title=f'Preprocessing Time for Hybrid, Kyber-$n$.', figsize=12 )
# Out:
# sec_param: 0.16666666666666666
# report_prehyb_160_3329_ternary_0.1667_0_6_52_53_51.pkl
# report_prehyb_160_3329_ternary_0.1667_1_6_52_53_51.pkl
# report_prehyb_160_3329_ternary_0.1667_2_6_52_53_51.pkl
# report_prehyb_160_3329_ternary_0.1667_3_6_52_53_51.pkl
# report_prehyb_160_3329_ternary_0.1667_4_6_52_53_51.pkl
# report_prehyb_160_3329_ternary_0.1667_5_6_52_53_51.pkl
# report_prehyb_160_3329_ternary_0.1667_6_6_52_53_51.pkl
# report_prehyb_160_3329_ternary_0.1667_7_6_52_53_51.pkl
# report_prehyb_160_3329_ternary_0.1667_8_6_52_53_51.pkl
# report_prehyb_160_3329_ternary_0.1667_9_6_52_53_51.pkl
# report_prehyb_170_3329_ternary_0.1667_0_6_55_56_54.pkl
# report_prehyb_170_3329_ternary_0.1667_1_6_57_58_56.pkl
# report_prehyb_170_3329_ternary_0.1667_2_6_57_58_56.pkl
# report_prehyb_170_3329_ternary_0.1667_3_6_57_58_56.pkl
# report_prehyb_170_3329_ternary_0.1667_4_6_57_58_56.pkl
# report_prehyb_170_3329_ternary_0.1667_5_6_57_58_56.pkl
# report_prehyb_170_3329_ternary_0.1667_6_6_57_58_56.pkl
# report_prehyb_170_3329_ternary_0.1667_7_6_57_58_56.pkl
# report_prehyb_170_3329_ternary_0.1667_8_6_57_58_56.pkl
# report_prehyb_170_3329_ternary_0.1667_9_6_57_58_56.pkl
# report_prehyb_180_3329_ternary_0.1667_0_6_62_63_61.pkl
# report_prehyb_180_3329_ternary_0.1667_0_6_65_66_64.pkl
# report_prehyb_180_3329_ternary_0.1667_1_6_65_66_64.pkl
# report_prehyb_180_3329_ternary_0.1667_2_6_65_66_64.pkl
# report_prehyb_180_3329_ternary_0.1667_3_6_65_66_64.pkl
# report_prehyb_180_3329_ternary_0.1667_4_6_65_66_64.pkl
# report_prehyb_180_3329_ternary_0.1667_5_6_65_66_64.pkl
# report_prehyb_180_3329_ternary_0.1667_6_6_65_66_64.pkl
# report_prehyb_180_3329_ternary_0.1667_7_6_65_66_64.pkl
# report_prehyb_180_3329_ternary_0.1667_8_6_65_66_64.pkl
# report_prehyb_180_3329_ternary_0.1667_9_6_65_66_64.pkl
# report_prehyb_190_3329_ternary_0.1667_0_6_75_76_74.pkl
# report_prehyb_190_3329_ternary_0.1667_1_6_75_76_74.pkl
# report_prehyb_190_3329_ternary_0.1667_2_6_75_76_74.pkl
# report_prehyb_190_3329_ternary_0.1667_3_6_75_76_74.pkl
# report_prehyb_190_3329_ternary_0.1667_4_6_75_76_74.pkl
# report_prehyb_190_3329_ternary_0.1667_5_6_75_76_74.pkl
# report_prehyb_190_3329_ternary_0.1667_6_6_75_76_74.pkl
# report_prehyb_190_3329_ternary_0.1667_7_6_75_76_74.pkl
# report_prehyb_190_3329_ternary_0.1667_8_6_75_76_74.pkl
# report_prehyb_190_3329_ternary_0.1667_9_6_75_76_74.pkl
# report_prehyb_200_3329_ternary_0.1667_0_6_84_85_83.pkl
# report_prehyb_200_3329_ternary_0.1667_1_6_84_85_83.pkl
# report_prehyb_200_3329_ternary_0.1667_2_6_84_85_83.pkl
# report_prehyb_200_3329_ternary_0.1667_3_6_84_85_83.pkl
# report_prehyb_200_3329_ternary_0.1667_4_6_84_85_83.pkl
# report_prehyb_200_3329_ternary_0.1667_5_6_84_85_83.pkl
# report_prehyb_200_3329_ternary_0.1667_6_6_84_85_83.pkl
# report_prehyb_200_3329_ternary_0.1667_7_6_84_85_83.pkl
# report_prehyb_200_3329_ternary_0.1667_8_6_84_85_83.pkl
# report_prehyb_200_3329_ternary_0.1667_9_6_84_85_83.pkl
# {160: 2869.25882645305, 170: 4439.56988387136, 180: 21651.9678163246, 190: 72802.2300150574, 200: 131515.778448624}
# {160: 720.0554124912402, 170: 1792.976082338089, 180: 3728.206810460752, 190: 9364.948915975121, 200: 17819.620214891715}
# Graphics object consisting of 2 graphics primitives

# %%
L = {}
available_ns = []
"""
The tha files now have a new naming convention.
"""

data = []
path = "./lwe_instances/reduced_lattices/"
pattern = re.compile(r'''
    ^tph_                          
    (?P<n>\d+)_                    
    (?P<dist>[^_]+)_               
    (?P<dist_param>[+-]?\d+\.\d{4})_  
    (?P<kappa>\d+)_                
    (?P<beta_bkz>\d+)_             
    (?P<sieve_dim_max>\d+)         
    \.pkl$                         
''', re.VERBOSE)
regex = re.compile(pattern)

lol=0
max_n = 0
for path, directories, files in os.walk(path):
    lol+=1
    for candidate in files:
        match = regex.match(candidate)
        print(f"aaaa: {candidate} | {match}")
        if match and sec_type in candidate and f"{sec_param:0.4f}" in candidate:
            gd = match.groupdict()
            n             = int(gd['n'])
            dist          = gd['dist']
            dist_param    = float(gd['dist_param'])
            kappa         = int(gd['kappa'])
            sieve_dim_max = int(gd['sieve_dim_max'])
            beta_bkz      = int(gd['beta_bkz'])
            
            available_ns.append(n)
            with open(path+candidate,"rb") as file:
                L.update( pickle.load(file) )
            

wtimes = {}
succs = {}
for n in available_ns:
    wtimes[n] = []
    if not n in succs:
        succs[n] = [0,0]
    
NRAND_FACTOR = 10.
for key in L:
    n, _, n_slicer_coord, n_guess_coord, _ = key
    print(n,n_guess_coord,n_slicer_coord)
    print( n_guess_coord == hparams[n][0] )
    if n_guess_coord == hparams[n][0]:
        print( n,n_guess_coord, hparams[n][0] )
        nrand_, _ = batchCVPP_cost(n_slicer_coord,100,L[key]["g6k_len"] **(1./n_slicer_coord),1)
        nrand = ceil(NRAND_FACTOR*(1./nrand_)**n_slicer_coord)
        utar_per_batch = ceil( L[key]["g6k_len"] / nrand ) #how many unique targets in batch
    
        curtime = abs( L[key]["wrong_guess_time_alg2"] ) + abs( L[key]["wrong_guess_time_alg3"] )
        overhead_tsieve = L[key]["overhead_tsieve"]
        batnum = L[key]["key_num"]/utar_per_batch
        curtime *= batnum  #time * how many batches needed
        wtimes[n].append( curtime + overhead_tsieve )
        succs[n][0]+=1
        succs[n][1]+=L[key]['succ']

for n in available_ns:
    wtimes[n] = np.mean(wtimes[n])
    try:
        # print(n)
        cur_succ_rate = float(succs[n][1] / succs[n][0])
    except TypeError:
        cur_succ_rate = succs[n]
    succs[n] = cur_succ_rate if cur_succ_rate>0 else 1/100.

ltot_hyb_att = {}
for key in wtimes.keys():
    walltime = wtimes[key]
    ltot_hyb_att[key] = l1[key] + ( 2*walltime ) / succs[key]  #success rate is 1/2 * slicer's proba

P += list_plot_semilogy(ltot_hyb_att, plotjoined=True, base=10, axes_labels=["$n$", "$log(T)$"], color="red", legend_label="Hybrid total")
plotfilename = f"time_{dist}_{dist_param:0.4f}_{available_ns}.png"
P.show( title=f'Preprocessing + attack Time for Hybrid, Kyber-$n$. Ternary {dist_param}', figsize=12 )
# Out:
# aaaa: exp_[140, 150, 160, 170]_3329_binomial_3.pkl | None
# aaaa: exp_[160, 170, 180, 190, 200]_3329_ternary_0.1667.pkl | None
# aaaa: report_prehyb_140_3329_binomial_3.0000_0_1_62_63_61.pkl | None
# aaaa: report_prehyb_140_3329_binomial_3.0000_1_1_62_63_61.pkl | None
# aaaa: report_prehyb_140_3329_binomial_3.0000_2_1_62_63_61.pkl | None
# aaaa: report_prehyb_140_3329_binomial_3.0000_3_1_62_63_61.pkl | None
# aaaa: report_prehyb_140_3329_binomial_3.0000_4_1_62_63_61.pkl | None
# aaaa: report_prehyb_140_3329_binomial_3.0000_5_1_62_63_61.pkl | None
# aaaa: report_prehyb_140_3329_binomial_3.0000_6_1_62_63_61.pkl | None
# aaaa: report_prehyb_140_3329_binomial_3.0000_7_1_62_63_61.pkl | None
# aaaa: report_prehyb_140_3329_binomial_3.0000_8_1_62_63_61.pkl | None
# aaaa: report_prehyb_140_3329_binomial_3.0000_9_1_62_63_61.pkl | None
# aaaa: report_prehyb_150_3329_binomial_3.0000_0_1_72_73_71.pkl | None
# aaaa: report_prehyb_150_3329_binomial_3.0000_1_1_72_73_71.pkl | None
# aaaa: report_prehyb_150_3329_binomial_3.0000_2_1_72_73_71.pkl | None
# aaaa: report_prehyb_150_3329_binomial_3.0000_3_1_72_73_71.pkl | None
# aaaa: report_prehyb_150_3329_binomial_3.0000_4_1_72_73_71.pkl | None
# aaaa: report_prehyb_150_3329_binomial_3.0000_5_1_72_73_71.pkl | None
# aaaa: report_prehyb_150_3329_binomial_3.0000_6_1_72_73_71.pkl | None
# aaaa: report_prehyb_150_3329_binomial_3.0000_7_1_72_73_71.pkl | None
# aaaa: report_prehyb_150_3329_binomial_3.0000_8_1_72_73_71.pkl | None
# aaaa: report_prehyb_150_3329_binomial_3.0000_9_1_72_73_71.pkl | None
# aaaa: report_prehyb_160_3329_binomial_3.0000_0_1_82_83_81.pkl | None
# aaaa: report_prehyb_160_3329_binomial_3.0000_1_1_82_83_81.pkl | None
# aaaa: report_prehyb_160_3329_binomial_3.0000_2_1_82_83_81.pkl | None
# aaaa: report_prehyb_160_3329_binomial_3.0000_3_1_82_83_81.pkl | None
# aaaa: report_prehyb_160_3329_binomial_3.0000_4_1_82_83_81.pkl | None
# aaaa: report_prehyb_160_3329_binomial_3.0000_5_1_82_83_81.pkl | None
# aaaa: report_prehyb_160_3329_binomial_3.0000_6_1_82_83_81.pkl | None
# aaaa: report_prehyb_160_3329_binomial_3.0000_7_1_82_83_81.pkl | None
# aaaa: report_prehyb_160_3329_binomial_3.0000_8_1_82_83_81.pkl | None
# aaaa: report_prehyb_160_3329_binomial_3.0000_9_1_82_83_81.pkl | None
# aaaa: report_prehyb_160_3329_ternary_0.1667_0_6_52_53_51.pkl | None
# aaaa: report_prehyb_160_3329_ternary_0.1667_1_6_52_53_51.pkl | None
# aaaa: report_prehyb_160_3329_ternary_0.1667_2_6_52_53_51.pkl | None
# aaaa: report_prehyb_160_3329_ternary_0.1667_3_6_52_53_51.pkl | None
# aaaa: report_prehyb_160_3329_ternary_0.1667_4_6_52_53_51.pkl | None
# aaaa: report_prehyb_160_3329_ternary_0.1667_5_6_52_53_51.pkl | None
# aaaa: report_prehyb_160_3329_ternary_0.1667_6_6_52_53_51.pkl | None
# aaaa: report_prehyb_160_3329_ternary_0.1667_7_6_52_53_51.pkl | None
# aaaa: report_prehyb_160_3329_ternary_0.1667_8_6_52_53_51.pkl | None
# aaaa: report_prehyb_160_3329_ternary_0.1667_9_6_52_53_51.pkl | None
# aaaa: report_prehyb_170_3329_binomial_3.0000_0_1_92_93_91.pkl | None
# aaaa: report_prehyb_170_3329_binomial_3.0000_1_1_92_93_91.pkl | None
# aaaa: report_prehyb_170_3329_binomial_3.0000_2_1_92_93_91.pkl | None
# aaaa: report_prehyb_170_3329_binomial_3.0000_3_1_92_93_91.pkl | None
# aaaa: report_prehyb_170_3329_binomial_3.0000_4_1_92_93_91.pkl | None
# aaaa: report_prehyb_170_3329_binomial_3.0000_5_1_92_93_91.pkl | None
# aaaa: report_prehyb_170_3329_binomial_3.0000_6_1_92_93_91.pkl | None
# aaaa: report_prehyb_170_3329_binomial_3.0000_7_1_92_93_91.pkl | None
# aaaa: report_prehyb_170_3329_binomial_3.0000_8_1_92_93_91.pkl | None
# aaaa: report_prehyb_170_3329_binomial_3.0000_9_1_92_93_91.pkl | None
# aaaa: report_prehyb_170_3329_ternary_0.1667_0_6_55_56_54.pkl | None
# aaaa: report_prehyb_170_3329_ternary_0.1667_1_6_57_58_56.pkl | None
# aaaa: report_prehyb_170_3329_ternary_0.1667_2_6_57_58_56.pkl | None
# aaaa: report_prehyb_170_3329_ternary_0.1667_3_6_57_58_56.pkl | None
# aaaa: report_prehyb_170_3329_ternary_0.1667_4_6_57_58_56.pkl | None
# aaaa: report_prehyb_170_3329_ternary_0.1667_5_6_57_58_56.pkl | None
# aaaa: report_prehyb_170_3329_ternary_0.1667_6_6_57_58_56.pkl | None
# aaaa: report_prehyb_170_3329_ternary_0.1667_7_6_57_58_56.pkl | None
# aaaa: report_prehyb_170_3329_ternary_0.1667_8_6_57_58_56.pkl | None
# aaaa: report_prehyb_170_3329_ternary_0.1667_9_6_57_58_56.pkl | None
# aaaa: report_prehyb_180_3329_ternary_0.0833_0_8_54_55_53.pkl | None
# aaaa: report_prehyb_180_3329_ternary_0.0833_1_8_54_55_53.pkl | None
# aaaa: report_prehyb_180_3329_ternary_0.0833_2_8_54_55_53.pkl | None
# aaaa: report_prehyb_180_3329_ternary_0.0833_3_8_54_55_53.pkl | None
# aaaa: report_prehyb_180_3329_ternary_0.0833_4_8_54_55_53.pkl | None
# aaaa: report_prehyb_180_3329_ternary_0.0833_5_8_54_55_53.pkl | None
# aaaa: report_prehyb_180_3329_ternary_0.0833_6_8_54_55_53.pkl | None
# aaaa: report_prehyb_180_3329_ternary_0.0833_7_8_54_55_53.pkl | None
# aaaa: report_prehyb_180_3329_ternary_0.0833_8_8_54_55_53.pkl | None
# aaaa: report_prehyb_180_3329_ternary_0.0833_9_8_54_55_53.pkl | None
# aaaa: report_prehyb_180_3329_ternary_0.1667_0_6_62_63_61.pkl | None
# aaaa: report_prehyb_180_3329_ternary_0.1667_0_6_65_66_64.pkl | None
# aaaa: report_prehyb_180_3329_ternary_0.1667_1_6_65_66_64.pkl | None
# aaaa: report_prehyb_180_3329_ternary_0.1667_2_6_65_66_64.pkl | None
# aaaa: report_prehyb_180_3329_ternary_0.1667_3_6_65_66_64.pkl | None
# aaaa: report_prehyb_180_3329_ternary_0.1667_4_6_65_66_64.pkl | None
# aaaa: report_prehyb_180_3329_ternary_0.1667_5_6_65_66_64.pkl | None
# aaaa: report_prehyb_180_3329_ternary_0.1667_6_6_65_66_64.pkl | None
# aaaa: report_prehyb_180_3329_ternary_0.1667_7_6_65_66_64.pkl | None
# aaaa: report_prehyb_180_3329_ternary_0.1667_8_6_65_66_64.pkl | None
# aaaa: report_prehyb_180_3329_ternary_0.1667_9_6_65_66_64.pkl | None
# aaaa: report_prehyb_190_3329_ternary_0.0833_0_8_61_62_60.pkl | None
# aaaa: report_prehyb_190_3329_ternary_0.0833_1_8_61_62_60.pkl | None
# aaaa: report_prehyb_190_3329_ternary_0.0833_2_8_61_62_60.pkl | None
# aaaa: report_prehyb_190_3329_ternary_0.0833_3_8_61_62_60.pkl | None
# aaaa: report_prehyb_190_3329_ternary_0.0833_4_8_61_62_60.pkl | None
# aaaa: report_prehyb_190_3329_ternary_0.0833_5_8_61_62_60.pkl | None
# aaaa: report_prehyb_190_3329_ternary_0.0833_6_8_61_62_60.pkl | None
# aaaa: report_prehyb_190_3329_ternary_0.0833_7_8_61_62_60.pkl | None
# aaaa: report_prehyb_190_3329_ternary_0.0833_8_8_61_62_60.pkl | None
# aaaa: report_prehyb_190_3329_ternary_0.0833_9_8_61_62_60.pkl | None
# aaaa: report_prehyb_190_3329_ternary_0.1667_0_6_75_76_74.pkl | None
# aaaa: report_prehyb_190_3329_ternary_0.1667_1_6_75_76_74.pkl | None
# aaaa: report_prehyb_190_3329_ternary_0.1667_2_6_75_76_74.pkl | None
# aaaa: report_prehyb_190_3329_ternary_0.1667_3_6_75_76_74.pkl | None
# aaaa: report_prehyb_190_3329_ternary_0.1667_4_6_75_76_74.pkl | None
# aaaa: report_prehyb_190_3329_ternary_0.1667_5_6_75_76_74.pkl | None
# aaaa: report_prehyb_190_3329_ternary_0.1667_6_6_75_76_74.pkl | None
# aaaa: report_prehyb_190_3329_ternary_0.1667_7_6_75_76_74.pkl | None
# aaaa: report_prehyb_190_3329_ternary_0.1667_8_6_75_76_74.pkl | None
# aaaa: report_prehyb_190_3329_ternary_0.1667_9_6_75_76_74.pkl | None
# aaaa: report_prehyb_200_3329_ternary_0.0833_0_8_68_69_67.pkl | None
# aaaa: report_prehyb_200_3329_ternary_0.0833_1_8_68_69_67.pkl | None
# aaaa: report_prehyb_200_3329_ternary_0.0833_2_8_68_69_67.pkl | None
# aaaa: report_prehyb_200_3329_ternary_0.0833_3_8_68_69_67.pkl | None
# aaaa: report_prehyb_200_3329_ternary_0.0833_4_8_68_69_67.pkl | None
# aaaa: report_prehyb_200_3329_ternary_0.0833_5_8_68_69_67.pkl | None
# aaaa: report_prehyb_200_3329_ternary_0.0833_6_8_68_69_67.pkl | None
# aaaa: report_prehyb_200_3329_ternary_0.0833_7_8_68_69_67.pkl | None
# aaaa: report_prehyb_200_3329_ternary_0.0833_8_8_68_69_67.pkl | None
# aaaa: report_prehyb_200_3329_ternary_0.0833_9_8_68_69_67.pkl | None
# aaaa: report_prehyb_200_3329_ternary_0.1667_0_6_84_85_83.pkl | None
# aaaa: report_prehyb_200_3329_ternary_0.1667_1_6_84_85_83.pkl | None
# aaaa: report_prehyb_200_3329_ternary_0.1667_2_6_84_85_83.pkl | None
# aaaa: report_prehyb_200_3329_ternary_0.1667_3_6_84_85_83.pkl | None
# aaaa: report_prehyb_200_3329_ternary_0.1667_4_6_84_85_83.pkl | None
# aaaa: report_prehyb_200_3329_ternary_0.1667_5_6_84_85_83.pkl | None
# aaaa: report_prehyb_200_3329_ternary_0.1667_6_6_84_85_83.pkl | None
# aaaa: report_prehyb_200_3329_ternary_0.1667_7_6_84_85_83.pkl | None
# aaaa: report_prehyb_200_3329_ternary_0.1667_8_6_84_85_83.pkl | None
# aaaa: report_prehyb_200_3329_ternary_0.1667_9_6_84_85_83.pkl | None
# aaaa: report_pre_140_3329_3_1_0_55.pkl | None
# aaaa: report_pre_140_3329_3_1_1_55.pkl | None
# aaaa: report_pre_140_3329_3_1_2_55.pkl | None
# aaaa: report_pre_140_3329_3_1_3_55.pkl | None
# aaaa: report_pre_140_3329_3_1_4_55.pkl | None
# aaaa: report_pre_140_3329_3_1_5_55.pkl | None
# aaaa: report_pre_140_3329_3_1_6_55.pkl | None
# aaaa: report_pre_140_3329_3_1_7_55.pkl | None
# aaaa: report_pre_140_3329_3_1_8_55.pkl | None
# aaaa: report_pre_140_3329_3_1_9_55.pkl | None
# aaaa: report_pre_150_3329_3_1_0_55.pkl | None
# aaaa: report_pre_150_3329_3_1_1_55.pkl | None
# aaaa: report_pre_150_3329_3_1_2_55.pkl | None
# aaaa: report_pre_150_3329_3_1_3_55.pkl | None
# aaaa: report_pre_150_3329_3_1_4_55.pkl | None
# aaaa: report_pre_150_3329_3_1_5_55.pkl | None
# aaaa: report_pre_150_3329_3_1_6_55.pkl | None
# aaaa: report_pre_150_3329_3_1_7_55.pkl | None
# aaaa: report_pre_150_3329_3_1_8_55.pkl | None
# aaaa: report_pre_150_3329_3_1_9_55.pkl | None
# aaaa: report_pre_160_3329_3_1_0_55.pkl | None
# aaaa: report_pre_160_3329_3_1_1_55.pkl | None
# aaaa: report_pre_160_3329_3_1_2_55.pkl | None
# aaaa: report_pre_160_3329_3_1_3_55.pkl | None
# aaaa: report_pre_160_3329_3_1_4_55.pkl | None
# aaaa: report_pre_160_3329_3_1_5_55.pkl | None
# aaaa: report_pre_160_3329_3_1_6_55.pkl | None
# aaaa: report_pre_160_3329_3_1_7_55.pkl | None
# aaaa: report_pre_160_3329_3_1_8_55.pkl | None
# aaaa: report_pre_160_3329_3_1_9_55.pkl | None
# aaaa: report_pre_160_3329_ternary_0.1667_0_50.pkl | None
# aaaa: report_pre_160_3329_ternary_0.1667_1_50.pkl | None
# aaaa: report_pre_160_3329_ternary_0.1667_2_50.pkl | None
# aaaa: report_pre_160_3329_ternary_0.1667_3_50.pkl | None
# aaaa: report_pre_160_3329_ternary_0.1667_4_50.pkl | None
# aaaa: report_pre_160_3329_ternary_0.1667_5_50.pkl | None
# aaaa: report_pre_160_3329_ternary_0.1667_6_50.pkl | None
# aaaa: report_pre_160_3329_ternary_0.1667_7_50.pkl | None
# aaaa: report_pre_160_3329_ternary_0.1667_8_50.pkl | None
# aaaa: report_pre_160_3329_ternary_0.1667_9_50.pkl | None
# aaaa: report_pre_170_3329_3_1_0_80.pkl | None
# aaaa: report_pre_170_3329_3_1_1_80.pkl | None
# aaaa: report_pre_170_3329_3_1_2_80.pkl | None
# aaaa: report_pre_170_3329_3_1_3_80.pkl | None
# aaaa: report_pre_170_3329_3_1_4_80.pkl | None
# aaaa: report_pre_170_3329_3_1_5_80.pkl | None
# aaaa: report_pre_170_3329_3_1_6_80.pkl | None
# aaaa: report_pre_170_3329_3_1_7_80.pkl | None
# aaaa: report_pre_170_3329_3_1_8_80.pkl | None
# aaaa: report_pre_170_3329_3_1_9_80.pkl | None
# aaaa: report_pre_170_3329_ternary_0.1667_0_50.pkl | None
# aaaa: report_pre_170_3329_ternary_0.1667_1_50.pkl | None
# aaaa: report_pre_170_3329_ternary_0.1667_2_50.pkl | None
# aaaa: report_pre_170_3329_ternary_0.1667_3_50.pkl | None
# aaaa: report_pre_170_3329_ternary_0.1667_4_50.pkl | None
# aaaa: report_pre_170_3329_ternary_0.1667_5_50.pkl | None
# aaaa: report_pre_170_3329_ternary_0.1667_6_50.pkl | None
# aaaa: report_pre_170_3329_ternary_0.1667_7_50.pkl | None
# aaaa: report_pre_170_3329_ternary_0.1667_8_50.pkl | None
# aaaa: report_pre_170_3329_ternary_0.1667_9_50.pkl | None
# aaaa: report_pre_180_3329_3_1_0_90.pkl | None
# aaaa: report_pre_180_3329_3_1_1_90.pkl | None
# aaaa: report_pre_180_3329_3_1_2_90.pkl | None
# aaaa: report_pre_180_3329_3_1_3_90.pkl | None
# aaaa: report_pre_180_3329_3_1_4_90.pkl | None
# aaaa: report_pre_180_3329_3_1_5_90.pkl | None
# aaaa: report_pre_180_3329_3_1_6_90.pkl | None
# aaaa: report_pre_180_3329_3_1_7_90.pkl | None
# aaaa: report_pre_180_3329_3_1_8_90.pkl | None
# aaaa: report_pre_180_3329_3_1_9_90.pkl | None
# aaaa: report_pre_180_3329_ternary_0.1667_0_60.pkl | None
# aaaa: report_pre_180_3329_ternary_0.1667_1_60.pkl | None
# aaaa: report_pre_180_3329_ternary_0.1667_2_60.pkl | None
# aaaa: report_pre_180_3329_ternary_0.1667_3_60.pkl | None
# aaaa: report_pre_180_3329_ternary_0.1667_4_60.pkl | None
# aaaa: report_pre_180_3329_ternary_0.1667_5_60.pkl | None
# aaaa: report_pre_180_3329_ternary_0.1667_6_60.pkl | None
# aaaa: report_pre_180_3329_ternary_0.1667_7_60.pkl | None
# aaaa: report_pre_180_3329_ternary_0.1667_8_60.pkl | None
# aaaa: report_pre_180_3329_ternary_0.1667_9_60.pkl | None
# aaaa: report_pre_190_3329_ternary_0.1667_0_60.pkl | None
# aaaa: report_pre_190_3329_ternary_0.1667_1_60.pkl | None
# aaaa: report_pre_190_3329_ternary_0.1667_2_60.pkl | None
# aaaa: report_pre_190_3329_ternary_0.1667_3_60.pkl | None
# aaaa: report_pre_190_3329_ternary_0.1667_4_60.pkl | None
# aaaa: report_pre_190_3329_ternary_0.1667_5_60.pkl | None
# aaaa: report_pre_190_3329_ternary_0.1667_6_60.pkl | None
# aaaa: report_pre_190_3329_ternary_0.1667_7_60.pkl | None
# aaaa: report_pre_190_3329_ternary_0.1667_8_60.pkl | None
# aaaa: report_pre_190_3329_ternary_0.1667_9_60.pkl | None
# aaaa: report_pre_200_3329_ternary_0.1667_0_65.pkl | None
# aaaa: report_pre_200_3329_ternary_0.1667_1_65.pkl | None
# aaaa: report_pre_200_3329_ternary_0.1667_2_65.pkl | None
# aaaa: report_pre_200_3329_ternary_0.1667_3_65.pkl | None
# aaaa: report_pre_200_3329_ternary_0.1667_4_65.pkl | None
# aaaa: report_pre_200_3329_ternary_0.1667_5_65.pkl | None
# aaaa: report_pre_200_3329_ternary_0.1667_6_65.pkl | None
# aaaa: report_pre_200_3329_ternary_0.1667_7_65.pkl | None
# aaaa: report_pre_200_3329_ternary_0.1667_8_65.pkl | None
# aaaa: report_pre_200_3329_ternary_0.1667_9_65.pkl | None
# aaaa: tph_140_binomial_3.0000_1_61_67.pkl | <re.Match object; span=(0, 35), match='tph_140_binomial_3.0000_1_61_67.pkl'>
# aaaa: tph_150_binomial_3.0000_1_71_77.pkl | <re.Match object; span=(0, 35), match='tph_150_binomial_3.0000_1_71_77.pkl'>
# aaaa: tph_160_binomial_3.0000_1_81_87.pkl | <re.Match object; span=(0, 35), match='tph_160_binomial_3.0000_1_81_87.pkl'>
# aaaa: tph_160_ternary_0.1667_6_52_58.pkl | <re.Match object; span=(0, 34), match='tph_160_ternary_0.1667_6_52_58.pkl'>
# aaaa: tph_170_binomial_3.0000_1_91_93.pkl | <re.Match object; span=(0, 35), match='tph_170_binomial_3.0000_1_91_93.pkl'>
# aaaa: tph_170_ternary_0.1667_6_57_63.pkl | <re.Match object; span=(0, 34), match='tph_170_ternary_0.1667_6_57_63.pkl'>
# aaaa: tph_180_ternary_0.1667_6_65_71.pkl | <re.Match object; span=(0, 34), match='tph_180_ternary_0.1667_6_65_71.pkl'>
# aaaa: tph_190_ternary_0.1667_6_75_81.pkl | <re.Match object; span=(0, 34), match='tph_190_ternary_0.1667_6_75_81.pkl'>
# aaaa: tph_200_ternary_0.1667_6_84_90.pkl | <re.Match object; span=(0, 34), match='tph_200_ternary_0.1667_6_84_90.pkl'>
# 160 6 53
# True
# 160 6 6
# 160 6 53
# True
# 160 6 6
# 160 6 53
# True
# 160 6 6
# 160 6 53
# True
# 160 6 6
# 160 6 53
# True
# 160 6 6
# 160 6 53
# True
# 160 6 6
# 160 6 53
# True
# 160 6 6
# 160 6 53
# True
# 160 6 6
# 160 6 53
# True
# 160 6 6
# 160 6 53
# True
# 160 6 6
# 160 6 53
# True
# 160 6 6
# 160 6 53
# True
# 160 6 6
# 160 6 53
# True
# 160 6 6
# 160 6 53
# True
# 160 6 6
# 160 6 53
# True
# 160 6 6
# 160 6 53
# True
# 160 6 6
# 160 6 53
# True
# 160 6 6
# 160 6 53
# True
# 160 6 6
# 160 6 53
# True
# 160 6 6
# 160 6 53
# True
# 160 6 6
# 160 6 53
# True
# 160 6 6
# 160 6 53
# True
# 160 6 6
# 160 6 53
# True
# 160 6 6
# 160 6 53
# True
# 160 6 6
# 160 6 53
# True
# 160 6 6
# 160 6 53
# True
# 160 6 6
# 160 6 53
# True
# 160 6 6
# 160 6 53
# True
# 160 6 6
# 160 6 53
# True
# 160 6 6
# 160 6 53
# True
# 160 6 6
# 160 6 53
# True
# 160 6 6
# 160 6 53
# True
# 160 6 6
# 160 6 53
# True
# 160 6 6
# 160 6 53
# True
# 160 6 6
# 160 6 53
# True
# 160 6 6
# 160 6 53
# True
# 160 6 6
# 160 6 53
# True
# 160 6 6
# 160 6 53
# True
# 160 6 6
# 160 6 53
# True
# 160 6 6
# 160 6 53
# True
# 160 6 6
# 160 6 53
# True
# 160 6 6
# 160 6 53
# True
# 160 6 6
# 160 6 53
# True
# 160 6 6
# 160 6 53
# True
# 160 6 6
# 160 6 53
# True
# 160 6 6
# 160 6 53
# True
# 160 6 6
# 160 6 53
# True
# 160 6 6
# 160 6 53
# True
# 160 6 6
# 160 6 53
# True
# 160 6 6
# 160 6 53
# True
# 160 6 6
# 160 6 53
# True
# 160 6 6
# 160 6 53
# True
# 160 6 6
# 160 6 53
# True
# 160 6 6
# 160 6 53
# True
# 160 6 6
# 160 6 53
# True
# 160 6 6
# 160 6 53
# True
# 160 6 6
# 160 6 53
# True
# 160 6 6
# 160 6 53
# True
# 160 6 6
# 160 6 53
# True
# 160 6 6
# 160 6 53
# True
# 160 6 6
# 160 6 53
# True
# 160 6 6
# 160 6 53
# True
# 160 6 6
# 160 6 53
# True
# 160 6 6
# 160 6 53
# True
# 160 6 6
# 160 6 53
# True
# 160 6 6
# 160 6 53
# True
# 160 6 6
# 160 6 53
# True
# 160 6 6
# 160 6 53
# True
# 160 6 6
# 160 6 53
# True
# 160 6 6
# 160 6 53
# True
# 160 6 6
# 160 6 53
# True
# 160 6 6
# 160 6 53
# True
# 160 6 6
# 160 6 53
# True
# 160 6 6
# 160 6 53
# True
# 160 6 6
# 160 6 53
# True
# 160 6 6
# 160 6 53
# True
# 160 6 6
# 160 6 53
# True
# 160 6 6
# 160 6 53
# True
# 160 6 6
# 160 6 53
# True
# 160 6 6
# 160 6 53
# True
# 160 6 6
# 160 6 53
# True
# 160 6 6
# 160 6 53
# True
# 160 6 6
# 160 6 53
# True
# 160 6 6
# 160 6 53
# True
# 160 6 6
# 160 6 53
# True
# 160 6 6
# 160 6 53
# True
# 160 6 6
# 160 6 53
# True
# 160 6 6
# 160 6 53
# True
# 160 6 6
# 160 6 53
# True
# 160 6 6
# 160 6 53
# True
# 160 6 6
# 160 6 53
# True
# 160 6 6
# 160 6 53
# True
# 160 6 6
# 160 6 53
# True
# 160 6 6
# 160 6 53
# True
# 160 6 6
# 160 6 53
# True
# 160 6 6
# 160 6 53
# True
# 160 6 6
# 160 6 53
# True
# 160 6 6
# 160 6 53
# True
# 160 6 6
# 160 6 53
# True
# 160 6 6
# 160 6 53
# True
# 160 6 6
# 170 6 63
# True
# 170 6 6
# 170 6 63
# True
# 170 6 6
# 170 6 63
# True
# 170 6 6
# 170 6 63
# True
# 170 6 6
# 170 6 63
# True
# 170 6 6
# 170 6 63
# True
# 170 6 6
# 170 6 63
# True
# 170 6 6
# 170 6 63
# True
# 170 6 6
# 170 6 63
# True
# 170 6 6
# 170 6 63
# True
# 170 6 6
# 170 6 63
# True
# 170 6 6
# 170 6 63
# True
# 170 6 6
# 170 6 63
# True
# 170 6 6
# 170 6 63
# True
# 170 6 6
# 170 6 63
# True
# 170 6 6
# 170 6 63
# True
# 170 6 6
# 170 6 63
# True
# 170 6 6
# 170 6 63
# True
# 170 6 6
# 170 6 63
# True
# 170 6 6
# 170 6 63
# True
# 170 6 6
# 170 6 62
# True
# 170 6 6
# 170 6 62
# True
# 170 6 6
# 170 6 62
# True
# 170 6 6
# 170 6 62
# True
# 170 6 6
# 170 6 62
# True
# 170 6 6
# 170 6 62
# True
# 170 6 6
# 170 6 62
# True
# 170 6 6
# 170 6 62
# True
# 170 6 6
# 170 6 62
# True
# 170 6 6
# 170 6 62
# True
# 170 6 6
# 170 6 63
# True
# 170 6 6
# 170 6 63
# True
# 170 6 6
# 170 6 63
# True
# 170 6 6
# 170 6 63
# True
# 170 6 6
# 170 6 63
# True
# 170 6 6
# 170 6 63
# True
# 170 6 6
# 170 6 63
# True
# 170 6 6
# 170 6 63
# True
# 170 6 6
# 170 6 63
# True
# 170 6 6
# 170 6 63
# True
# 170 6 6
# 170 6 63
# True
# 170 6 6
# 170 6 63
# True
# 170 6 6
# 170 6 63
# True
# 170 6 6
# 170 6 63
# True
# 170 6 6
# 170 6 63
# True
# 170 6 6
# 170 6 63
# True
# 170 6 6
# 170 6 63
# True
# 170 6 6
# 170 6 63
# True
# 170 6 6
# 170 6 63
# True
# 170 6 6
# 170 6 63
# True
# 170 6 6
# 170 6 62
# True
# 170 6 6
# 170 6 62
# True
# 170 6 6
# 170 6 62
# True
# 170 6 6
# 170 6 62
# True
# 170 6 6
# 170 6 62
# True
# 170 6 6
# 170 6 62
# True
# 170 6 6
# 170 6 62
# True
# 170 6 6
# 170 6 62
# True
# 170 6 6
# 170 6 62
# True
# 170 6 6
# 170 6 62
# True
# 170 6 6
# 170 6 63
# True
# 170 6 6
# 170 6 63
# True
# 170 6 6
# 170 6 63
# True
# 170 6 6
# 170 6 63
# True
# 170 6 6
# 170 6 63
# True
# 170 6 6
# 170 6 63
# True
# 170 6 6
# 170 6 63
# True
# 170 6 6
# 170 6 63
# True
# 170 6 6
# 170 6 63
# True
# 170 6 6
# 170 6 63
# True
# 170 6 6
# 170 6 63
# True
# 170 6 6
# 170 6 63
# True
# 170 6 6
# 170 6 63
# True
# 170 6 6
# 170 6 63
# True
# 170 6 6
# 170 6 63
# True
# 170 6 6
# 170 6 63
# True
# 170 6 6
# 170 6 63
# True
# 170 6 6
# 170 6 63
# True
# 170 6 6
# 170 6 63
# True
# 170 6 6
# 170 6 63
# True
# 170 6 6
# 170 6 62
# True
# 170 6 6
# 170 6 62
# True
# 170 6 6
# 170 6 62
# True
# 170 6 6
# 170 6 62
# True
# 170 6 6
# 170 6 62
# True
# 170 6 6
# 170 6 62
# True
# 170 6 6
# 170 6 62
# True
# 170 6 6
# 170 6 62
# True
# 170 6 6
# 170 6 62
# True
# 170 6 6
# 170 6 62
# True
# 170 6 6
# 170 6 63
# True
# 170 6 6
# 170 6 63
# True
# 170 6 6
# 170 6 63
# True
# 170 6 6
# 170 6 63
# True
# 170 6 6
# 170 6 63
# True
# 170 6 6
# 170 6 63
# True
# 170 6 6
# 170 6 63
# True
# 170 6 6
# 170 6 63
# True
# 170 6 6
# 170 6 63
# True
# 170 6 6
# 170 6 63
# True
# 170 6 6
# 180 6 71
# True
# 180 6 6
# 180 6 71
# True
# 180 6 6
# 180 6 71
# True
# 180 6 6
# 180 6 71
# True
# 180 6 6
# 180 6 71
# True
# 180 6 6
# 180 6 71
# True
# 180 6 6
# 180 6 71
# True
# 180 6 6
# 180 6 71
# True
# 180 6 6
# 180 6 71
# True
# 180 6 6
# 180 6 71
# True
# 180 6 6
# 180 6 71
# True
# 180 6 6
# 180 6 71
# True
# 180 6 6
# 180 6 71
# True
# 180 6 6
# 180 6 71
# True
# 180 6 6
# 180 6 71
# True
# 180 6 6
# 180 6 71
# True
# 180 6 6
# 180 6 71
# True
# 180 6 6
# 180 6 71
# True
# 180 6 6
# 180 6 71
# True
# 180 6 6
# 180 6 71
# True
# 180 6 6
# 180 6 71
# True
# 180 6 6
# 180 6 71
# True
# 180 6 6
# 180 6 71
# True
# 180 6 6
# 180 6 71
# True
# 180 6 6
# 180 6 71
# True
# 180 6 6
# 180 6 71
# True
# 180 6 6
# 180 6 71
# True
# 180 6 6
# 180 6 71
# True
# 180 6 6
# 180 6 71
# True
# 180 6 6
# 180 6 71
# True
# 180 6 6
# 180 6 71
# True
# 180 6 6
# 180 6 71
# True
# 180 6 6
# 180 6 71
# True
# 180 6 6
# 180 6 71
# True
# 180 6 6
# 180 6 71
# True
# 180 6 6
# 180 6 71
# True
# 180 6 6
# 180 6 71
# True
# 180 6 6
# 180 6 71
# True
# 180 6 6
# 180 6 71
# True
# 180 6 6
# 180 6 71
# True
# 180 6 6
# 180 6 71
# True
# 180 6 6
# 180 6 71
# True
# 180 6 6
# 180 6 71
# True
# 180 6 6
# 180 6 71
# True
# 180 6 6
# 180 6 71
# True
# 180 6 6
# 180 6 71
# True
# 180 6 6
# 180 6 71
# True
# 180 6 6
# 180 6 71
# True
# 180 6 6
# 180 6 71
# True
# 180 6 6
# 180 6 71
# True
# 180 6 6
# 180 6 71
# True
# 180 6 6
# 180 6 71
# True
# 180 6 6
# 180 6 71
# True
# 180 6 6
# 180 6 71
# True
# 180 6 6
# 180 6 71
# True
# 180 6 6
# 180 6 71
# True
# 180 6 6
# 180 6 71
# True
# 180 6 6
# 180 6 71
# True
# 180 6 6
# 180 6 71
# True
# 180 6 6
# 180 6 71
# True
# 180 6 6
# 180 6 71
# True
# 180 6 6
# 180 6 71
# True
# 180 6 6
# 180 6 71
# True
# 180 6 6
# 180 6 71
# True
# 180 6 6
# 180 6 71
# True
# 180 6 6
# 180 6 71
# True
# 180 6 6
# 180 6 71
# True
# 180 6 6
# 180 6 71
# True
# 180 6 6
# 180 6 71
# True
# 180 6 6
# 180 6 71
# True
# 180 6 6
# 180 6 70
# True
# 180 6 6
# 180 6 70
# True
# 180 6 6
# 180 6 70
# True
# 180 6 6
# 180 6 70
# True
# 180 6 6
# 180 6 70
# True
# 180 6 6
# 180 6 70
# True
# 180 6 6
# 180 6 70
# True
# 180 6 6
# 180 6 70
# True
# 180 6 6
# 180 6 70
# True
# 180 6 6
# 180 6 70
# True
# 180 6 6
# 180 6 71
# True
# 180 6 6
# 180 6 71
# True
# 180 6 6
# 180 6 71
# True
# 180 6 6
# 180 6 71
# True
# 180 6 6
# 180 6 71
# True
# 180 6 6
# 180 6 71
# True
# 180 6 6
# 180 6 71
# True
# 180 6 6
# 180 6 71
# True
# 180 6 6
# 180 6 71
# True
# 180 6 6
# 180 6 71
# True
# 180 6 6
# 180 6 70
# True
# 180 6 6
# 180 6 70
# True
# 180 6 6
# 180 6 70
# True
# 180 6 6
# 180 6 70
# True
# 180 6 6
# 180 6 70
# True
# 180 6 6
# 180 6 70
# True
# 180 6 6
# 180 6 70
# True
# 180 6 6
# 180 6 70
# True
# 180 6 6
# 180 6 70
# True
# 180 6 6
# 180 6 70
# True
# 180 6 6
# 190 6 77
# True
# 190 6 6
# 190 6 77
# True
# 190 6 6
# 190 6 77
# True
# 190 6 6
# 190 6 77
# True
# 190 6 6
# 190 6 77
# True
# 190 6 6
# 190 6 77
# True
# 190 6 6
# 190 6 77
# True
# 190 6 6
# 190 6 77
# True
# 190 6 6
# 190 6 77
# True
# 190 6 6
# 190 6 77
# True
# 190 6 6
# 190 6 77
# True
# 190 6 6
# 190 6 77
# True
# 190 6 6
# 190 6 77
# True
# 190 6 6
# 190 6 77
# True
# 190 6 6
# 190 6 77
# True
# 190 6 6
# 190 6 77
# True
# 190 6 6
# 190 6 77
# True
# 190 6 6
# 190 6 77
# True
# 190 6 6
# 190 6 77
# True
# 190 6 6
# 190 6 77
# True
# 190 6 6
# 190 6 77
# True
# 190 6 6
# 190 6 77
# True
# 190 6 6
# 190 6 77
# True
# 190 6 6
# 190 6 77
# True
# 190 6 6
# 190 6 77
# True
# 190 6 6
# 190 6 77
# True
# 190 6 6
# 190 6 77
# True
# 190 6 6
# 190 6 77
# True
# 190 6 6
# 190 6 77
# True
# 190 6 6
# 190 6 77
# True
# 190 6 6
# 190 6 77
# True
# 190 6 6
# 190 6 77
# True
# 190 6 6
# 190 6 77
# True
# 190 6 6
# 190 6 77
# True
# 190 6 6
# 190 6 77
# True
# 190 6 6
# 190 6 77
# True
# 190 6 6
# 190 6 77
# True
# 190 6 6
# 190 6 77
# True
# 190 6 6
# 190 6 77
# True
# 190 6 6
# 190 6 77
# True
# 190 6 6
# 190 6 77
# True
# 190 6 6
# 190 6 77
# True
# 190 6 6
# 190 6 77
# True
# 190 6 6
# 190 6 77
# True
# 190 6 6
# 190 6 77
# True
# 190 6 6
# 190 6 77
# True
# 190 6 6
# 190 6 77
# True
# 190 6 6
# 190 6 77
# True
# 190 6 6
# 190 6 77
# True
# 190 6 6
# 190 6 77
# True
# 190 6 6
# 190 6 78
# True
# 190 6 6
# 190 6 78
# True
# 190 6 6
# 190 6 78
# True
# 190 6 6
# 190 6 78
# True
# 190 6 6
# 190 6 78
# True
# 190 6 6
# 190 6 78
# True
# 190 6 6
# 190 6 78
# True
# 190 6 6
# 190 6 78
# True
# 190 6 6
# 190 6 78
# True
# 190 6 6
# 190 6 78
# True
# 190 6 6
# 190 6 77
# True
# 190 6 6
# 190 6 77
# True
# 190 6 6
# 190 6 77
# True
# 190 6 6
# 190 6 77
# True
# 190 6 6
# 190 6 77
# True
# 190 6 6
# 190 6 77
# True
# 190 6 6
# 190 6 77
# True
# 190 6 6
# 190 6 77
# True
# 190 6 6
# 190 6 77
# True
# 190 6 6
# 190 6 77
# True
# 190 6 6
# 190 6 76
# True
# 190 6 6
# 190 6 76
# True
# 190 6 6
# 190 6 76
# True
# 190 6 6
# 190 6 76
# True
# 190 6 6
# 190 6 76
# True
# 190 6 6
# 190 6 76
# True
# 190 6 6
# 190 6 76
# True
# 190 6 6
# 190 6 76
# True
# 190 6 6
# 190 6 76
# True
# 190 6 6
# 190 6 76
# True
# 190 6 6
# 190 6 77
# True
# 190 6 6
# 190 6 77
# True
# 190 6 6
# 190 6 77
# True
# 190 6 6
# 190 6 77
# True
# 190 6 6
# 190 6 77
# True
# 190 6 6
# 190 6 77
# True
# 190 6 6
# 190 6 77
# True
# 190 6 6
# 190 6 77
# True
# 190 6 6
# 190 6 77
# True
# 190 6 6
# 190 6 77
# True
# 190 6 6
# 190 6 77
# True
# 190 6 6
# 190 6 77
# True
# 190 6 6
# 190 6 77
# True
# 190 6 6
# 190 6 77
# True
# 190 6 6
# 190 6 77
# True
# 190 6 6
# 190 6 77
# True
# 190 6 6
# 190 6 77
# True
# 190 6 6
# 190 6 77
# True
# 190 6 6
# 190 6 77
# True
# 190 6 6
# 190 6 77
# True
# 190 6 6
# 200 6 85
# True
# 200 6 6
# 200 6 85
# True
# 200 6 6
# 200 6 85
# True
# 200 6 6
# 200 6 85
# True
# 200 6 6
# 200 6 85
# True
# 200 6 6
# 200 6 85
# True
# 200 6 6
# 200 6 85
# True
# 200 6 6
# 200 6 85
# True
# 200 6 6
# 200 6 85
# True
# 200 6 6
# 200 6 85
# True
# 200 6 6
# 200 6 85
# True
# 200 6 6
# 200 6 85
# True
# 200 6 6
# 200 6 85
# True
# 200 6 6
# 200 6 85
# True
# 200 6 6
# 200 6 85
# True
# 200 6 6
# 200 6 85
# True
# 200 6 6
# 200 6 85
# True
# 200 6 6
# 200 6 85
# True
# 200 6 6
# 200 6 85
# True
# 200 6 6
# 200 6 85
# True
# 200 6 6
# 200 6 85
# True
# 200 6 6
# 200 6 85
# True
# 200 6 6
# 200 6 85
# True
# 200 6 6
# 200 6 85
# True
# 200 6 6
# 200 6 85
# True
# 200 6 6
# 200 6 85
# True
# 200 6 6
# 200 6 85
# True
# 200 6 6
# 200 6 85
# True
# 200 6 6
# 200 6 85
# True
# 200 6 6
# 200 6 85
# True
# 200 6 6
# 200 6 85
# True
# 200 6 6
# 200 6 85
# True
# 200 6 6
# 200 6 85
# True
# 200 6 6
# 200 6 85
# True
# 200 6 6
# 200 6 85
# True
# 200 6 6
# 200 6 85
# True
# 200 6 6
# 200 6 85
# True
# 200 6 6
# 200 6 85
# True
# 200 6 6
# 200 6 85
# True
# 200 6 6
# 200 6 85
# True
# 200 6 6
# 200 6 85
# True
# 200 6 6
# 200 6 85
# True
# 200 6 6
# 200 6 85
# True
# 200 6 6
# 200 6 85
# True
# 200 6 6
# 200 6 85
# True
# 200 6 6
# 200 6 85
# True
# 200 6 6
# 200 6 85
# True
# 200 6 6
# 200 6 85
# True
# 200 6 6
# 200 6 85
# True
# 200 6 6
# 200 6 85
# True
# 200 6 6
# 200 6 85
# True
# 200 6 6
# 200 6 85
# True
# 200 6 6
# 200 6 85
# True
# 200 6 6
# 200 6 85
# True
# 200 6 6
# 200 6 85
# True
# 200 6 6
# 200 6 85
# True
# 200 6 6
# 200 6 85
# True
# 200 6 6
# 200 6 85
# True
# 200 6 6
# 200 6 85
# True
# 200 6 6
# 200 6 85
# True
# 200 6 6
# 200 6 85
# True
# 200 6 6
# 200 6 85
# True
# 200 6 6
# 200 6 85
# True
# 200 6 6
# 200 6 85
# True
# 200 6 6
# 200 6 85
# True
# 200 6 6
# 200 6 85
# True
# 200 6 6
# 200 6 85
# True
# 200 6 6
# 200 6 85
# True
# 200 6 6
# 200 6 85
# True
# 200 6 6
# 200 6 85
# True
# 200 6 6
# 200 6 85
# True
# 200 6 6
# 200 6 85
# True
# 200 6 6
# 200 6 85
# True
# 200 6 6
# 200 6 85
# True
# 200 6 6
# 200 6 85
# True
# 200 6 6
# 200 6 85
# True
# 200 6 6
# 200 6 85
# True
# 200 6 6
# 200 6 85
# True
# 200 6 6
# 200 6 85
# True
# 200 6 6
# 200 6 85
# True
# 200 6 6
# 200 6 85
# True
# 200 6 6
# 200 6 85
# True
# 200 6 6
# 200 6 85
# True
# 200 6 6
# 200 6 85
# True
# 200 6 6
# 200 6 85
# True
# 200 6 6
# 200 6 85
# True
# 200 6 6
# 200 6 85
# True
# 200 6 6
# 200 6 85
# True
# 200 6 6
# 200 6 85
# True
# 200 6 6
# 200 6 85
# True
# 200 6 6
# 200 6 85
# True
# 200 6 6
# 200 6 85
# True
# 200 6 6
# 200 6 85
# True
# 200 6 6
# 200 6 85
# True
# 200 6 6
# 200 6 85
# True
# 200 6 6
# 200 6 85
# True
# 200 6 6
# 200 6 85
# True
# 200 6 6
# 200 6 85
# True
# 200 6 6
# 200 6 85
# True
# 200 6 6
# 200 6 85
# True
# 200 6 6
# Graphics object consisting of 3 graphics primitives

# %%
t = np.array( [ [1,2,3], [4,5,6] ] )
np.mean( t,axis=1 )
# Out:
# array([2., 5.])

# %%
sec_type
# Out:
# 'ternary'

# %%
aggrigated_data.keys()
# Out:
# dict_keys([(160, 6, 53), (160, 6, 52), (170, 6, 58), (170, 6, 57), (180, 6, 66), (180, 6, 65), (200, 6, 85), (200, 6, 84)])

# %%
45*60
# Out:
# 2700
